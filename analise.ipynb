# %% [raw]
# f#%%
# import pandas as pd

# %%
df = pd.read_csv('residencial.csv', sep=';')
# Out:
#                   Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0            Quitinete       Copacabana        1      0       0    40
# 5   Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 9          Apartamento       Copacabana        1      0       1    40
# 10           Quitinete       Copacabana        1      0       0    27
# 11         Apartamento       Copacabana        4      3       1   243
# 14         Apartamento  Barra da Tijuca        2      1       1    67
# 15         Apartamento           Tijuca        2      1       0   110
# 16  Casa de Condomínio  Barra da Tijuca        4      3       2   466
# 18         Apartamento           Tijuca        2      1       0    78
# 19         Apartamento          Ipanema        3      1       1   125
#
#       Valor  Condominio   IPTU  Valor m2 Tipo Agregado
# 0    1700.0       500.0   60.0     42.50   Apartamento
# 5   22000.0         0.0    0.0     29.33          Casa
# ...

# %%
df.head(10)
# Out:
# 6432.60027832351

# %%
df['Valor'].mean()
# Out:
# array(['Copacabana', 'Barra da Tijuca', 'Tijuca', 'Ipanema', 'Botafogo',
#        'Leblon', 'Flamengo'], dtype=object)

# %%
df.Bairro.unique()

# %%
bairros = ['Barra da Tijuca', 'Copacabana', 'Ipanema', 'Leblon', 'Botafogo', 'Flamengo', 'Tijuca']
selecao = df['Bairro'].isin(bairros)
df = df[selecao]
# Out:
# 0          Copacabana
# 5     Barra da Tijuca
# 15             Tijuca
# 19            Ipanema
# 23           Botafogo
# 27             Leblon
# 78           Flamengo
# Name: Bairro, dtype: object

# %%
df['Bairro'].drop_duplicates()

# %%
grupo_bairro = df.groupby('Bairro')

# %%
grupo_bairro
# Out:
# {'Barra da Tijuca': [5, 14, 16, 21, 30, 32, 35, 42, 43, 60, 61, 64, 68, 74, 79, 93, 107, 110, 112, 117, 130, 132, 136, 150, 153, 155, 165, 166, 173, 186, 189, 207, 214, 221, 224, 233, 236, 239, 244, 259, 265, 274, 276, 291, 292, 293, 295, 302, 308, 311, 325, 335, 336, 345, 360, 366, 368, 374, 380, 387, 389, 400, 412, 432, 433, 435, 436, 439, 449, 451, 462, 463, 465, 473, 476, 484, 494, 500, 503, 511, 537, 538, 539, 540, 543, 547, 552, 554, 555, 556, 584, 587, 588, 590, 594, 596, 601, 611, 622, 630, ...], 'Botafogo': [23, 48, 87, 88, 111, 119, 127, 134, 196, 200, 225, 334, 362, 415, 416, 498, 524, 526, 545, 593, 649, 685, 719, 756, 765, 822, 827, 861, 915, 924, 928, 1006, 1043, 1080, 1091, 1110, 1116, 1127, 1140, 1165, 1201, 1205, 1223, 1250, 1282, 1295, 1304, 1317, 1348, 1383, 1414, 1419, 1455, 1517, 1529, 1579, 1630, 1655, 1670, 1699, 1741, 1742, 1788, 1814, 1823, 1826, 1853, 1922, 1931, 1957, 1972, 1981, 1989, 2029, 2066, 2069, 2081, 2083, 2084, 2088, 2097, 2148, 2149, 2165, 2179, 
# ...

# %%
grupo_bairro.groups
# Out:
# Barra da Tijuca
# Botafogo
# Copacabana
# Flamengo
# Ipanema
# Leblon
# Tijuca

# %%
for bairro, dados in grupo_bairro:
    print(bairro)
# Out:
#                      Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 5      Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 14            Apartamento  Barra da Tijuca        2      1       1    67
# 16     Casa de Condomínio  Barra da Tijuca        4      3       2   466
# 21            Apartamento  Barra da Tijuca        3      3       1   175
# 30            Apartamento  Barra da Tijuca        3      1       2    70
# ...                   ...              ...      ...    ...     ...   ...
# 21801  Casa de Condomínio  Barra da Tijuca        3      5       3  1000
# 21811         Apartamento  Barra da Tijuca        2      1       1    85
# 21812         Apartamento  Barra da Tijuca        3      2       0    98
# 21813         Apartamento  Barra da Tijuca        3      2       2   140
# 21820  Casa de Condomínio  Barra da Tijuca        5      3       4   450
#
#          Valor  Condominio    IPTU  Valor m2 Tipo Agregado
# ...

# %%
for bairro, dados in grupo_bairro:
    print(dados)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
for bairro, dados in grupo_bairro:
    print(type(dados))
# Out:
# Barra da Tijuca -> 7069.552938130986
# Botafogo -> 8791.828178694159
# Copacabana -> 4126.677004538578
# Flamengo -> 4113.526610644258
# Ipanema -> 9352.001133786847
# Leblon -> 8746.344992050874
# Tijuca -> 2043.52

# %%
for bairro, dados in grupo_bairro:
    print('{} -> {}'.format(bairro, dados.Valor.mean()))
# Out:
# C:\Users\LAS2\AppData\Local\Temp\ipykernel_4324\3736357955.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grupo_bairro['Valor', 'Condominio'].mean().round(2)
#                    Valor  Condominio
# Bairro
# Barra da Tijuca  7069.55     3591.01
# Botafogo         8791.83      976.28
# Copacabana       4126.68     1148.68
# Flamengo         4113.53     1102.15
# Ipanema          9352.00     2244.44
# Leblon           8746.34     2107.18
# Tijuca           2043.52      711.69

# %%
grupo_bairro['Valor', 'Condominio'].mean().round(2)

# %% [markdown]
# ## Estatisticas Descritivas

# %%
grupo_bairro['Valor'].describe().round(2)
# Out:
#                  Minimo     Maximo
# Bairro
# Barra da Tijuca   800.0   600000.0
# Botafogo          700.0  4500000.0
# Copacabana        100.0    35000.0
# Flamengo          800.0    35000.0
# Ipanema          1200.0    90000.0
# Leblon            100.0   100000.0
# Tijuca            750.0    45000.0

# %%
grupo_bairro['Valor'].aggregate(['min', 'max']).rename(columns={'min': 'Minimo', 'max': 'Maximo'})

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rc('figure', figsize = (14, 6))
# Out:
# Text(0.5, 1.0, 'Valor Médio do Aluguel por Bairro')

# %%
fig_mean = grupo_bairro['Valor'].mean().plot.bar(color = 'blue')
fig_mean.set_ylabel('Valor do Alguel')
fig_mean.set_title('Valor Médio do Aluguel por Bairro', {'fontsize': 22})
# Out:
# Text(0.5, 1.0, 'Valor Maximo do Aluguel por Bairro')

# %%
fig_max = grupo_bairro['Valor'].max().plot.bar(color = 'blue')
fig_max.set_ylabel('Valor do Alguel')
fig_max.set_title('Valor Maximo do Aluguel por Bairro', {'fontsize': 22})
# Out:
# Text(0.5, 1.0, 'Valor Medio do Condominio por Bairro')

# %%
fig_cond_mean = grupo_bairro['Condominio'].mean().plot.bar(color = 'blue')
fig_cond_mean.set_ylabel('Valor do Condominio')
fig_cond_mean.set_title('Valor Medio do Condominio por Bairro', {'fontsize': 22})
# Out:
#                      Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0               Quitinete       Copacabana        1      0       0    40
# 5      Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 9             Apartamento       Copacabana        1      0       1    40
# 10              Quitinete       Copacabana        1      0       0    27
# 11            Apartamento       Copacabana        4      3       1   243
# ...                   ...              ...      ...    ...     ...   ...
# 21816         Apartamento           Leblon        3      0       1    80
# 21817         Apartamento          Ipanema        3      1       2   150
# 21818         Apartamento           Tijuca        1      0       0    28
# 21820  Casa de Condomínio  Barra da Tijuca        5      3       4   450
# 21825         Apartamento           Leblon        2      0       0    70
#
#          Valor  Condominio    IPTU  Valor m2 Tipo Agregado
# ...

# %%
df
# Out:
# <AxesSubplot:>

# %%
df.boxplot(['Valor'])
# Out:
#               Tipo           Bairro  Quartos  Vagas  Suites  Area      Valor  \
# 7629   Apartamento  Barra da Tijuca        1      1       0    65   600000.0
# 15520  Apartamento         Botafogo        4      1       1   300  4500000.0
#
#        Condominio   IPTU  Valor m2 Tipo Agregado
# 7629        980.0  120.0   9230.77   Apartamento
# 15520      1100.0    0.0  15000.00   Apartamento

# %%
df[df['Valor'] >= 500000]

# %%
valor = df['Valor']
# Out:
# 0         1700.0
# 5        22000.0
# 9         2000.0
# 10        1800.0
# 11       13000.0
#           ...
# 21816     3000.0
# 21817    15000.0
# 21818     1000.0
# 21820    15000.0
# 21825     3000.0
# Name: Valor, Length: 12216, dtype: float64

# %%
valor

# %%
Q1 = valor.quantile(.25)
Q3 = valor.quantile(.75)
IIQ = Q3 - Q1
limite_inferior = Q1 - 1.5 * IIQ
limite_superior = Q3 + 1.5 * IIQ

# %%
selecao = (valor >= limite_inferior) & (valor <= limite_superior)
df_new = df[selecao]
# Out:
# <AxesSubplot:>

# %%
df_new.boxplot(['Valor'])

# %%
# Out:
# array([[<AxesSubplot:title={'center':'Valor'}>]], dtype=object)

# %%
df_new.hist(['Valor'])
